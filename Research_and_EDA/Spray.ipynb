# %%
import pandas as pd
import numpy as np

# %%
from datetime import datetime

# %%
path = '../Assets/spray.csv'

# %%
spray = pd.read_csv(path)

# %%
spray['Date'] = pd.to_datetime(spray.Date)

# %%
# spray.set_index('Date', inplace=True)

# %%
np.unique(spray.Date)
# Out:
# array(['2011-08-28T20:00:00.000000000-0400',
#        '2011-09-06T20:00:00.000000000-0400',
#        '2013-07-16T20:00:00.000000000-0400',
#        '2013-07-24T20:00:00.000000000-0400',
#        '2013-08-07T20:00:00.000000000-0400',
#        '2013-08-14T20:00:00.000000000-0400',
#        '2013-08-15T20:00:00.000000000-0400',
#        '2013-08-21T20:00:00.000000000-0400',
#        '2013-08-28T20:00:00.000000000-0400',
#        '2013-09-04T20:00:00.000000000-0400'], dtype='datetime64[ns]')

# %%
c = [datetime(2011, 8, 28), datetime(2011, 9, 6), datetime(2013, 7, 16), datetime(2013, 7, 24),
     datetime(2013, 8, 7), datetime(2013, 8, 14), datetime(2013, 8, 15), datetime(2013, 8, 21),
     datetime(2013, 8, 28), datetime(2013, 9, 4)]

# %%
path_merged = '../Assets/merged.csv'

# %%
merged = pd.read_csv(path_merged)

# %%
merged['Date'] = pd.to_datetime(merged.Date)

# %%
for i in merged.Date:
    c[0] - i
# Out:
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1552 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# 1545 days 00:00:00
# ...
